# %% [markdown]
# 소프트웨어학부 20186663 전찬웅

# %% [markdown]
# 0. Prepared

# %%
import csv
list_train_x = [[],[],[],[]]
list_train_y = []
list_test_x = [[],[],[],[]]
list_test_y = []
with open('data_train.csv', newline='') as myfile:
    reader  = csv.reader(myfile, delimiter=',')
    ct = 1 
    for i in reader:
        i[0]=float(i[0])
        i[1]=float(i[1])
        i[2]=float(i[2])
        i[3]=float(i[3])
        list_train_x[0].append(float(1))
        list_train_x[1].append(i[0])
        list_train_x[2].append(i[1])
        list_train_x[3].append(i[2])
        list_train_y.append(i[3])
        ct += 1

with open('data_test.csv', newline='') as myfile:
    reader  = csv.reader(myfile, delimiter=',')
    ct = 1 
    for i in reader:
        i[0]=float(i[0])
        i[1]=float(i[1])
        i[2]=float(i[2])
        i[3]=float(i[3])
        list_test_x[0].append(float(1))
        list_test_x[1].append(i[0])
        list_test_x[2].append(i[1])
        list_test_x[3].append(i[2])
        list_test_y.append(i[3])
        ct += 1

# %%
import numpy as np
X_train = np.array(list_train_x)
X_test = np.array(list_test_x)
y_train =np.array(list_train_y)
y_test = np.array(list_test_y)
y_train = y_train.reshape(1,-1)
y_test = y_test.reshape(1,-1)

# %% [markdown]
# 1. Plot the estimated parameters using the training dataset

# %%
import matplotlib.pyplot as plt

obj1 = []
theta1 = [[],[],[],[]]
learning_rate =0.00001
m = len(y_train[0])
W1 = np.random.rand(1,4)
for i in range(3000000):
    cost1 = np.sum((np.dot(W1,X_train)-y_train)**2)/(2*m)
    for k in range(4):
        theta1[k].append(W1[0][k])
    obj1.append(cost)
    W1 = W1 - learning_rate*(((np.dot(W1,X_train)-y_train)*X_train).sum(axis=1))/m
    
plt.figure(figsize=(14, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment4-1(W)")
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(range(3000000),theta1[0],color='k',label='theta0')
plt.plot(range(3000000),theta1[1],color='r',label='theta1')
plt.plot(range(3000000),theta1[2],color='g',label='theta2')
plt.plot(range(3000000),theta1[3],color='b',label='theta3')
plt.show()

# %% [markdown]
# 그래프를 통하여 theta0,1,2,3이 수렴함을 알 수 있다

# %%
obj1 = []
theta1 = [[],[],[],[]]
learning_rate =0.00001
m = len(y_train[0])
W1 = np.random.rand(1,4)
for i in range(300000):
    cost1 = np.sum((np.dot(W1,X_train)-y_train)**2)/(2*m)
    for k in range(4):
        theta1[k].append(W1[0][k])
    obj1.append(cost)
    W1 = W1 - learning_rate*(((np.dot(W1,X_train)-y_train)*X_train).sum(axis=1))/m
    
plt.figure(figsize=(14, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment4-1(W)")
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(range(300000),theta1[0],color='k',label='theta0')
plt.plot(range(300000),theta1[1],color='r',label='theta1')
plt.plot(range(300000),theta1[2],color='g',label='theta2')
plt.plot(range(300000),theta1[3],color='b',label='theta3')
plt.show()

# %% [markdown]
# 그래프에서 초반30만번만 확인했을때 theta1,2,3의 수렴을 확실히 알 수 있다

# %%
2. Plot the training error using
