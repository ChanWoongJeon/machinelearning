# %% [markdown]
# assignment2-소프트웨어학부 20186663 전찬웅

# %% [markdown]
# 임의지정 random function y = 2*x+5/범위 (-5,5)/number of random point is 300

# %% [markdown]
# 2-1 Input data

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.

# %%
def func(x):
    return 2*x+5

# %%
x = np.random.rand(1, 300)*10-5
sigma = np.random.randn(1,300)
y= func(x)+sigma

# %%
plt.figure(figsize=(7, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment2-1")
plt.xlabel('X')
plt.ylabel('Y')
t1 = np.arange(-5.0, 5.0, 0.01)
plt.plot(t1,func(t1),color = 'b')
plt.scatter(x,y,color='k',s=3)
plt.show()

# %% [markdown]
# 2-2 Output results

# %%
theta = np.random.randn(1,2)
print(theta)
# Out:
# [[0.31949927 0.3963652 ]]

# %% [markdown]
# 초기 랜덤으로 직선 구했을때(red-line)/blue-line은 원래의 직선

# %%
plt.figure(figsize=(7, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment2-2")
plt.xlabel('X')
plt.ylabel('Y')
t1 = np.arange(-5.0, 5.0, 0.01)
plt.plot(t1,func(t1),color = 'b',label='original line')
plt.scatter(x,y,color='k',s=3)
plt.plot(t1,theta[0,0]*t1+theta[0,1],color='r',label='random line')
plt.show()

# %%
obj = []
a= []
b= []
for i in range(1000):
    a.append(theta[0,0])
    b.append(theta[0,1])
    y_pred=theta[0,0]*x+theta[0,1]
    obj.append((1/(2*300))*(np.sum((y_pred-y)**2)))
    theta[0,0]= theta[0,0]-(0.01/300)*(np.sum((y_pred-y)*x))
    theta[0,1]= theta[0,1]-(0.01/300)*(np.sum((y_pred-y)))

# %% [markdown]
# 1000번의 학습후 직선의 모양(red-line)

# %%
plt.figure(figsize=(7, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment2-2")
plt.xlabel('X')
plt.ylabel('Y')
t1 = np.arange(-5.0, 5.0, 0.01)
plt.scatter(x,y,color='k',s=3)
plt.plot(t1,theta[0,0]*t1+theta[0,1],color='r')
plt.show()
print("기울기 :",theta[0,0],"y절편:",theta[0,1])
print("원래함수와 거의 같다는것을 알 수 있다.")
# Out:
# 기울기 : 2.0337964247087172 y절편: 4.996243339577196
# 원래함수와 거의 같다는것을 알 수 있다.

# %% [markdown]
# 2-3. Plotting the energy values

# %%
plt.figure(figsize=(7, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment2-3(objective function)")
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(range(1000),obj,color='b')
plt.show()

# %% [markdown]
# 그래프를 통하여 object function은 0에 수렴함을 알 수 있다.

# %% [markdown]
# 2-4 Plotting the model parameters

# %%
plt.figure(figsize=(7, 7))
plt.axvline(x=0, color = 'r',linestyle=':')
plt.axhline(y=0, color = 'r',linestyle=':')
plt.title("assignment2-4(theta)")
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(range(1000),a,color='r',label='theta1')
plt.plot(range(1000),b,color='b',label='theta0')
plt.show()

# %% [markdown]
# 그래프를 통하여 theta0,theta1은 각각 5와 2에 수렴함을 알 수 있다.
